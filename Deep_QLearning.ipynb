# %%
import pandas as pd

def load_movielens_data(base_path: str) -> Tuple[Dict, Dict, Dict]:
    df_users = pd.read_csv(f'{base_path}/u.user', sep='|', encoding='latin-1',
                          names=['user_id', 'age', 'gender', 'occupation', 'zipcode'])
    df_users['stt'] = df_users['user_id']
    
    df_movies = pd.read_csv(f'{base_path}/u.item', sep='|', encoding='latin-1',
                           names=['movie_id', 'title', 'release_date', 'video_release_date', 
                                 'IMDb_URL'] + [f'genre_{i}' for i in range(19)])
    df_movies['stt'] = df_movies['movie_id']
    
    df_ratings = pd.read_csv(f'{base_path}/u.data', sep='\t', encoding='latin-1',
                            names=['user_id', 'movie_id', 'rating', 'timestamp'])
    
    users = df_users.set_index('stt').to_dict(orient='index')
    movies = df_movies.set_index('stt').to_dict(orient='index')
    ratings = {(row['user_id'], row['movie_id']): row['rating'] 
              for _, row in df_ratings.iterrows()}
    
    return users, movies, ratings

users, movies, ratings = load_movielens_data('ml-100k')
print(f"Số lượng users: {len(users)}")
print(f"Số lượng movies: {len(movies)}")
print(f"Số lượng ratings: {len(ratings)}")
# Out:
# Số lượng users: 943
# Số lượng movies: 1682
# Số lượng ratings: 100000

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque
from typing import Dict, List, Tuple
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

class MovieFeatureExtractor:
    """Extract and process movie features"""
    def __init__(self, movies_df: pd.DataFrame):
        self.movies_df = movies_df
        self.genre_columns = self._extract_genres()
        self.scaler = StandardScaler()
        self.features = self._build_features()
        
    def _extract_genres(self) -> List[str]:
        """Extract unique genres from movies dataset"""
        all_genres = set()
        for genres in self.movies_df['genres'].str.split('|'):
            if isinstance(genres, list):
                all_genres.update(genres)
        return sorted(list(all_genres))
    
    def _build_features(self) -> np.ndarray:
        """Build movie feature matrix"""
        # Create genre binary features
        genre_features = np.zeros((len(self.movies_df), len(self.genre_columns)))
        
        for i, genres in enumerate(self.movies_df['genres'].str.split('|')):
            if isinstance(genres, list):
                for genre in genres:
                    genre_idx = self.genre_columns.index(genre)
                    genre_features[i, genre_idx] = 1
                    
        # Combine with other numerical features if available
        numerical_features = []
        if 'vote_average' in self.movies_df.columns:
            numerical_features.append(self.movies_df['vote_average'].fillna(0))
        if 'runtime' in self.movies_df.columns:
            numerical_features.append(self.movies_df['runtime'].fillna(0))
            
        if numerical_features:
            numerical_features = np.column_stack(numerical_features)
            numerical_features = self.scaler.fit_transform(numerical_features)
            features = np.hstack([genre_features, numerical_features])
        else:
            features = genre_features
            
        return features
    
    def get_movie_features(self, movie_id: int) -> np.ndarray:
        """Get features for a specific movie"""
        movie_idx = self.movies_df[self.movies_df['movie_id'] == movie_id].index[0]
        return self.features[movie_idx]

class UserFeatureExtractor:
    """Extract and process user features"""
    def __init__(self, users_df: pd.DataFrame, ratings_df: pd.DataFrame):
        self.users_df = users_df
        self.ratings_df = ratings_df
        self.scaler = StandardScaler()
        self.features = self._build_features()
        
    def _build_features(self) -> np.ndarray:
        """Build user feature matrix"""
        # Calculate rating statistics for each user
        user_stats = self.ratings_df.groupby('user_id').agg({
            'rating': ['count', 'mean', 'std']
        }).fillna(0)
        user_stats.columns = ['rating_count', 'rating_mean', 'rating_std']
        
        # Normalize numerical features
        numerical_features = self.scaler.fit_transform(user_stats)
        
        # Create demographic features if available
        demographic_features = []
        if 'age' in self.users_df.columns:
            age_scaled = self.scaler.fit_transform(self.users_df[['age']])
            demographic_features.append(age_scaled)
            
        if 'occupation' in self.users_df.columns:
            occupation_dummies = pd.get_dummies(self.users_df['occupation'])
            demographic_features.append(occupation_dummies.values)
            
        if demographic_features:
            features = np.hstack([numerical_features] + demographic_features)
        else:
            features = numerical_features
            
        return features
    
    def get_user_features(self, user_id: int) -> np.ndarray:
        """Get features for a specific user"""
        user_idx = self.users_df[self.users_df['user_id'] == user_id].index[0]
        return self.features[user_idx]

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque
from typing import Dict, List, Tuple, Optional
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

class MovieFeatureExtractor:
    """Extract and process movie features"""
    def __init__(self, movies: Dict):
        self.movies = movies
        self.genre_columns = [f'genre_{i}' for i in range(19)]
        self.scaler = StandardScaler()
        self.features = self._build_features()
        
    def _build_features(self) -> np.ndarray:
        """Build movie feature matrix"""
        n_movies = len(self.movies)
        n_features = len(self.genre_columns)
        features = np.zeros((n_movies, n_features))
        
        for movie_id, movie_data in self.movies.items():
            for i, genre_col in enumerate(self.genre_columns):
                features[movie_id-1, i] = movie_data[genre_col]
                    
        return features
    
    def get_movie_features(self, movie_id: int) -> np.ndarray:
        """Get features for a specific movie"""
        return self.features[movie_id-1]

class UserFeatureExtractor:
    """Extract and process user features"""
    def __init__(self, users: Dict, ratings: Dict):
        self.users = users
        self.ratings = ratings
        self.scaler = StandardScaler()
        self.features = self._build_features()
        
    def _build_features(self) -> np.ndarray:
        """Build user feature matrix"""
        # Calculate rating statistics for each user
        user_stats = self._calculate_user_stats()
        
        # Create demographic features
        demographic_features = self._create_demographic_features()
        
        # Combine features
        features = np.hstack([user_stats, demographic_features])
        return self.scaler.fit_transform(features)
    
    def _calculate_user_stats(self) -> np.ndarray:
        """Calculate rating statistics for each user"""
        user_stats = {}
        for user_id in self.users.keys():
            user_ratings = [rating for (u_id, _), rating in self.ratings.items() if u_id == user_id]
            user_stats[user_id] = {
                'rating_count': len(user_ratings),
                'rating_mean': np.mean(user_ratings) if user_ratings else 0,
                'rating_std': np.std(user_ratings) if user_ratings else 0
            }
        
        stats_array = np.zeros((len(self.users), 3))
        for user_id, stats in user_stats.items():
            stats_array[user_id-1] = [stats['rating_count'], stats['rating_mean'], stats['rating_std']]
        return stats_array
    
    def _create_demographic_features(self) -> np.ndarray:
        """Create demographic features from user data"""
        n_users = len(self.users)
        
        # Age feature
        age_feature = np.zeros((n_users, 1))
        for user_id, user_data in self.users.items():
            age_feature[user_id-1] = user_data['age']
            
        # Gender feature (binary)
        gender_feature = np.zeros((n_users, 1))
        for user_id, user_data in self.users.items():
            gender_feature[user_id-1] = 1 if user_data['gender'] == 'M' else 0
            
        # Occupation one-hot encoding
        occupations = sorted(set(user['occupation'] for user in self.users.values()))
        occupation_features = np.zeros((n_users, len(occupations)))
        for user_id, user_data in self.users.items():
            occupation_idx = occupations.index(user_data['occupation'])
            occupation_features[user_id-1, occupation_idx] = 1
            
        return np.hstack([age_feature, gender_feature, occupation_features])
    
    def get_user_features(self, user_id: int) -> np.ndarray:
        """Get features for a specific user"""
        return self.features[user_id-1]

class MovieRecommenderEnv:
    """Environment for movie recommendation"""
    def __init__(self, users: Dict, movies: Dict, ratings: Dict, max_steps: int = 100):
        self.users = users
        self.movies = movies
        self.ratings = ratings
        self.max_steps = max_steps
        
        self.user_history = self._build_user_history()
        self.current_user = None
        self.current_movie = None
        self.steps = 0
        
    def _build_user_history(self) -> Dict[int, List[int]]:
        """Build dictionary of user rating history"""
        history = {}
        for (user_id, movie_id) in self.ratings.keys():
            if user_id not in history:
                history[user_id] = []
            history[user_id].append(movie_id)
        return history
    
    def reset(self) -> Tuple[int, int]:
        """Reset environment and return initial state"""
        self.steps = 0
        self.current_user = random.choice(list(self.users.keys()))
        available_movies = list(set(self.movies.keys()) - set(self.user_history.get(self.current_user, [])))
        self.current_movie = random.choice(available_movies) if available_movies else random.choice(list(self.movies.keys()))
        return self.current_user, self.current_movie
    
    def step(self, action: int) -> Tuple[Tuple[int, int], float]:
        """Take action and return next state and reward"""
        self.steps += 1
        
        # Calculate reward based on prediction accuracy
        true_rating = self.ratings.get((self.current_user, self.current_movie), None)
        if true_rating is not None:
            reward = -abs(true_rating - action)  # Negative absolute error as reward
        else:
            reward = -2.5  # Penalty for recommending already rated movie
        
        # Get next state
        if self.steps >= self.max_steps:
            return (self.current_user, self.current_movie), reward
            
        available_movies = list(set(self.movies.keys()) - set(self.user_history.get(self.current_user, [])))
        self.current_movie = random.choice(available_movies) if available_movies else random.choice(list(self.movies.keys()))
        
        return (self.current_user, self.current_movie), reward
    
    def evaluate(self) -> float:
        """Calculate RMSE on test set"""
        predictions = []
        true_ratings = []
        
        for (user_id, movie_id), rating in random.sample(list(self.ratings.items()), min(1000, len(self.ratings))):
            state = (user_id, movie_id)
            predicted_rating = self.predict(state)
            predictions.append(predicted_rating)
            true_ratings.append(rating)
            
        return np.sqrt(mean_squared_error(true_ratings, predictions))
    
    def predict(self, state: Tuple[int, int]) -> float:
        """Predict rating for a given state"""
        # This method will be implemented by the recommender system
        return 3.0  # Default prediction


class DQN(nn.Module):
    """Deep Q-Network architecture"""
    def __init__(self, input_dim: int, hidden_dims: List[int], output_dim: int):
        super(DQN, self).__init__()
        
        layers = []
        prev_dim = input_dim
        
        for hidden_dim in hidden_dims:
            layers.extend([
                nn.Linear(prev_dim, hidden_dim),
                nn.ReLU(),
                nn.Dropout(0.2)
            ])
            prev_dim = hidden_dim
            
        layers.append(nn.Linear(prev_dim, output_dim))
        
        self.network = nn.Sequential(*layers)
        
    def forward(self, x):
        return self.network(x)

class ReplayBuffer:
    """Experience replay buffer"""
    def __init__(self, capacity: int):
        self.buffer = deque(maxlen=capacity)
        
    def push(self, state, action, reward, next_state):
        self.buffer.append((state, action, reward, next_state))
        
    def sample(self, batch_size: int) -> List:
        return random.sample(self.buffer, min(batch_size, len(self.buffer)))
    
    def __len__(self) -> int:
        return len(self.buffer)

class DeepQRecommender:
    """Deep Q-Learning based movie recommender"""
    def __init__(self, env,
                 movie_features: MovieFeatureExtractor,
                 user_features: UserFeatureExtractor,
                 hidden_dims: List[int] = [128, 64],
                 learning_rate: float = 0.001,
                 gamma: float = 0.95,
                 epsilon_start: float = 1.0,
                 epsilon_end: float = 0.01,
                 epsilon_decay: float = 0.995,
                 buffer_size: int = 10000,
                 batch_size: int = 32,
                 target_update: int = 10):
        self.env = env
        self.movie_features = movie_features
        self.user_features = user_features
        self.possible_ratings = [1, 2, 3, 4, 5]
        
        # Calculate input dimension
        state_dim = (len(self.movie_features.get_movie_features(0)) + 
                    len(self.user_features.get_user_features(0)))
        
        # Initialize networks
        self.policy_net = DQN(state_dim, hidden_dims, len(self.possible_ratings))
        self.target_net = DQN(state_dim, hidden_dims, len(self.possible_ratings))
        self.target_net.load_state_dict(self.policy_net.state_dict())
        
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=learning_rate)
        self.memory = ReplayBuffer(buffer_size)
        
        # Training parameters
        self.gamma = gamma
        self.epsilon = epsilon_start
        self.epsilon_end = epsilon_end
        self.epsilon_decay = epsilon_decay
        self.batch_size = batch_size
        self.target_update = target_update
        self.steps_done = 0
        
    def get_state(self, user_id: int, movie_id: int) -> torch.Tensor:
        """Combine user and movie features into state"""
        movie_feat = self.movie_features.get_movie_features(movie_id)
        user_feat = self.user_features.get_user_features(user_id)
        state = np.concatenate([movie_feat, user_feat])
        return torch.FloatTensor(state)
    
    def select_action(self, state: torch.Tensor) -> int:
        """Select action using epsilon-greedy policy"""
        if random.random() > self.epsilon:
            with torch.no_grad():
                q_values = self.policy_net(state)
                return self.possible_ratings[q_values.argmax().item()]
        else:
            return random.choice(self.possible_ratings)
        
    def optimize_model(self):
        """Train the model using experience replay"""
        if len(self.memory) < self.batch_size:
            return
        
        transitions = self.memory.sample(self.batch_size)
        batch = list(zip(*transitions))
        
        state_batch = torch.stack(batch[0])
        action_batch = torch.tensor(batch[1])
        reward_batch = torch.tensor(batch[2])
        next_state_batch = torch.stack(batch[3])
        
        # Compute current Q values
        current_q_values = self.policy_net(state_batch).gather(1, 
            torch.tensor([[self.possible_ratings.index(a)] for a in action_batch]))
        
        # Compute next Q values
        next_q_values = self.target_net(next_state_batch).max(1)[0].detach()
        expected_q_values = reward_batch + self.gamma * next_q_values
        
        # Compute loss and optimize
        loss = nn.MSELoss()(current_q_values, expected_q_values.unsqueeze(1))
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
        # Update epsilon
        self.epsilon = max(self.epsilon_end, self.epsilon * self.epsilon_decay)
        
    def update_target_network(self):
        """Update target network weights"""
        if self.steps_done % self.target_update == 0:
            self.target_net.load_state_dict(self.policy_net.state_dict())
            
    def train(self, num_episodes: int):
        """Train the model"""
        rewards_history = []
        rmse_history = []
        
        for episode in range(num_episodes):
            state = self.env.reset()
            episode_rewards = []
            
            while True:
                # Convert state to tensor
                state_tensor = self.get_state(state[0], state[1])
                
                # Select and perform action
                action = self.select_action(state_tensor)
                next_state, reward = self.env.step(action)
                
                # Store transition
                next_state_tensor = self.get_state(next_state[0], next_state[1])
                self.memory.push(state_tensor, action, reward, next_state_tensor)
                
                # Update state
                state = next_state
                episode_rewards.append(reward)
                
                # Optimize model
                self.optimize_model()
                self.steps_done += 1
                
                # Update target network
                self.update_target_network()
                
                if len(episode_rewards) >= self.env.max_steps:
                    break
            
            # Calculate metrics
            avg_reward = np.mean(episode_rewards)
            rmse = self.env.evaluate()
            
            rewards_history.append(avg_reward)
            rmse_history.append(rmse)
            
            if episode % 100 == 0:
                print(f"Episode {episode}")
                print(f"Average Reward: {avg_reward:.4f}")
                print(f"RMSE: {rmse:.4f}")
                print(f"Epsilon: {self.epsilon:.4f}")
                print("------------------------")
                
        return rewards_history, rmse_history
    
    def recommend_movies(self, user_id: int, top_k: int = 5):
        """Recommend top-k movies for a user"""
        user_rated_movies = set(self.env.user_history.get(user_id, []))
        all_movies = set(self.env.movies.keys())
        unwatched_movies = list(all_movies - user_rated_movies)
        
        predictions = []
        for movie_id in unwatched_movies:
            state = self.get_state(user_id, movie_id)
            with torch.no_grad():
                q_values = self.policy_net(state)
                predicted_rating = self.possible_ratings[q_values.argmax().item()]
                confidence = torch.softmax(q_values, dim=0).max().item()
                predictions.append((movie_id, predicted_rating, confidence))
        
        # Sort by predicted rating and confidence
        predictions.sort(key=lambda x: (x[1], x[2]), reverse=True)
        
        top_recommendations = []
        for movie_id, pred_rating, conf in predictions[:top_k]:
            movie_info = self.env.movies[movie_id]
            top_recommendations.append({
                'movie_id': movie_id,
                'title': movie_info['title'],
                'predicted_rating': pred_rating,
                'confidence': conf
            })
            
        return top_recommendations

# %%
# Load data
users, movies, ratings = load_movielens_data('ml-100k')

# Initialize feature extractors
movie_features = MovieFeatureExtractor(movies)
user_features = UserFeatureExtractor(users, ratings)

# Initialize environment
env = MovieRecommenderEnv(users, movies, ratings)

# Initialize recommender
recommender = DeepQRecommender(
    env,
    movie_features=movie_features,
    user_features=user_features,
    hidden_dims=[128, 64],
    learning_rate=0.001,
    gamma=0.95,
    epsilon_start=1.0,
    epsilon_end=0.01,
    epsilon_decay=0.995,
    buffer_size=10000,
    batch_size=32,
    target_update=10
)

# Train model
rewards_history, rmse_history = recommender.train(num_episodes=100)
# Out:
# Episode 0
# Average Reward: -2.5000
# RMSE: 1.2377
# Epsilon: 0.7076
# ------------------------

# %%
# Get recommendations for a user
user_id = 1
recommendations = recommender.recommend_movies(user_id, 2000)

print("\nTop 5 movie recommendations for user", user_id)
for i, rec in enumerate(recommendations, 1):
    print(f"{i}. Movie: {rec['title']}")
    print(f"Predicted Rating: {rec['predicted_rating']:.1f}")
    print(f"Confidence: {rec['confidence']:.2f}")
    print("------------------------")
# Out:
# Top 5 movie recommendations for user 1
# 1. Movie: Fear, The (1995)
# Predicted Rating: 5.0
# Confidence: 0.34
# ------------------------
# 2. Movie: Once Upon a Time... When We Were Colored (1995)
# Predicted Rating: 5.0
# Confidence: 0.33
# ------------------------
# 3. Movie: Hideaway (1995)
# Predicted Rating: 5.0
# Confidence: 0.33
# ------------------------
# 4. Movie: Jaws 3-D (1983)
# Predicted Rating: 5.0
# Confidence: 0.32
# ------------------------
# 5. Movie: Bride of Frankenstein (1935)
# Predicted Rating: 5.0
# Confidence: 0.32
# ------------------------
# 6. Movie: Entertaining Angels: The Dorothy Day Story (1996)
# Predicted Rating: 5.0
# Confidence: 0.32
# ------------------------
# 7. Movie: Deceiver (1997)
# Predicted Rating: 5.0
# Confidence: 0.32
# ------------------------
# 8. Movie: Object of My Affection, The (1998)
# Predicted Rating: 5.0
# Confidence: 0.31
# ------------------------
# 9. Movie: Gate of Heavenly Peace, The (1995)
# Predicted Rating: 5.0
# Confidence: 0.31
# ------------------------
# 10. Movie: Thirty-Two Short Films About Glenn Gould (1993)
# Predicted Rating: 5.0
# Confidence: 0.31
# ------------------------
# 11. Movie: Switchblade Sisters (1975)
# Predicted Rating: 5.0
# Confidence: 0.31
# ------------------------
# 12. Movie: Rebel Without a Cause (1955)
# Predicted Rating: 5.0
# Confidence: 0.31
# ------------------------
# 13. Movie: Daytrippers, The (1996)
# Predicted Rating: 5.0
# Confidence: 0.30
# ------------------------
# 14. Movie: Wild Reeds (1994)
# Predicted Rating: 5.0
# Confidence: 0.30
# ------------------------
# 15. Movie: Big Bang Theory, The (1994)
# Predicted Rating: 5.0
# Confidence: 0.30
# ------------------------
# 16. Movie: It Happened One Night (1934)
# Predicted Rating: 5.0
# Confidence: 0.30
# ------------------------
# 17. Movie: Last Time I Saw Paris, The (1954)
# Predicted Rating: 5.0
# Confidence: 0.30
# ------------------------
# 18. Movie: Colonel Chabert, Le (1994)
# Predicted Rating: 5.0
# Confidence: 0.30
# ------------------------
# 19. Movie: Under Siege 2: Dark Territory (1995)
# Predicted Rating: 5.0
# Confidence: 0.30
# ------------------------
# 20. Movie: Faust (1994)
# Predicted Rating: 5.0
# Confidence: 0.30
# ------------------------
# 21. Movie: Cook the Thief His Wife & Her Lover, The (1989)
# Predicted Rating: 5.0
# Confidence: 0.30
# ------------------------
# 22. Movie: Kull the Conqueror (1997)
# Predicted Rating: 5.0
# Confidence: 0.30
# ------------------------
# 23. Movie: War, The (1994)
# Predicted Rating: 5.0
# Confidence: 0.30
# ------------------------
# 24. Movie: G.I. Jane (1997)
# Predicted Rating: 5.0
# Confidence: 0.29
# ------------------------
# 25. Movie: Poetic Justice (1993)
# Predicted Rating: 5.0
# Confidence: 0.29
# ------------------------
# 26. Movie: Dadetown (1995)
# Predicted Rating: 5.0
# Confidence: 0.29
# ------------------------
# 27. Movie: Pharaoh's Army (1995)
# Predicted Rating: 5.0
# Confidence: 0.29
# ------------------------
# 28. Movie: Rainmaker, The (1997)
# Predicted Rating: 5.0
# Confidence: 0.29
# ------------------------
# 29. Movie: Fox and the Hound, The (1981)
# Predicted Rating: 5.0
# Confidence: 0.29
# ------------------------
# 30. Movie: C'est arrivï¿½ prï¿½s de chez vous (1992)
# Predicted Rating: 5.0
# Confidence: 0.29
# ------------------------
# 31. Movie: Crows and Sparrows (1949)
# Predicted Rating: 5.0
# Confidence: 0.29
# ------------------------
# 32. Movie: Little Princess, A (1995)
# Predicted Rating: 5.0
# Confidence: 0.29
# ------------------------
# 33. Movie: Don Juan DeMarco (1995)
# Predicted Rating: 5.0
# Confidence: 0.29
# ------------------------
# 34. Movie: Hungarian Fairy Tale, A (1987)
# Predicted Rating: 5.0
# Confidence: 0.29
# ------------------------
# 35. Movie: Phat Beach (1996)
# Predicted Rating: 5.0
# Confidence: 0.29
# ------------------------
# 36. Movie: Roommates (1995)
# Predicted Rating: 5.0
# Confidence: 0.29
# ------------------------
# 37. Movie: Some Folks Call It a Sling Blade (1993)
# Predicted Rating: 5.0
# Confidence: 0.29
# ------------------------
# 38. Movie: Meet Me in St. Louis (1944)
# Predicted Rating: 5.0
# Confidence: 0.29
# ------------------------
# 39. Movie: Once Were Warriors (1994)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 40. Movie: Ice Storm, The (1997)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 41. Movie: Touch of Evil (1958)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 42. Movie: Ben-Hur (1959)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 43. Movie: Farinelli: il castrato (1994)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 44. Movie: Jason's Lyric (1994)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 45. Movie: Jerky Boys, The (1994)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 46. Movie: Last Summer in the Hamptons (1995)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 47. Movie: Red Corner (1997)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 48. Movie: Cronos (1992)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 49. Movie: Fog, The (1980)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 50. Movie: Infinity (1996)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 51. Movie: Body Snatcher, The (1945)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 52. Movie: Wings of Desire (1987)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 53. Movie: Moonlight and Valentino (1995)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 54. Movie: Safe (1995)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 55. Movie: My Man Godfrey (1936)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 56. Movie: Leading Man, The (1996)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 57. Movie: Harlem (1993)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 58. Movie: Joy Luck Club, The (1993)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 59. Movie: Vie est belle, La (Life is Rosey) (1987)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 60. Movie: Jackie Chan's First Strike (1996)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 61. Movie: Catwalk (1995)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 62. Movie: Normal Life (1996)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 63. Movie: Vertigo (1958)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 64. Movie: Paris, France (1993)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 65. Movie: Two Deaths (1995)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 66. Movie: Duoluo tianshi (1995)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 67. Movie: Swan Princess, The (1994)
# Predicted Rating: 5.0
# Confidence: 0.28
# ------------------------
# 68. Movie: Every Other Weekend (1990)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 69. Movie: Sleepers (1996)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 70. Movie: Boys on the Side (1995)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 71. Movie: Love Jones (1997)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 72. Movie: Michael (1996)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 73. Movie: City of Lost Children, The (1995)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 74. Movie: Second Jungle Book: Mowgli & Baloo, The (1997)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 75. Movie: Great Race, The (1965)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 76. Movie: Rent-a-Kid (1995)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 77. Movie: Savage Nights (Nuits fauves, Les) (1992)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 78. Movie: Of Human Bondage (1934)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 79. Movie: King of New York (1990)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 80. Movie: Women, The (1939)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 81. Movie: Very Brady Sequel, A (1996)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 82. Movie: Michael Collins (1996)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 83. Movie: Substance of Fire, The (1996)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 84. Movie: Grease (1978)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 85. Movie: Star Kid (1997)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 86. Movie: Naked (1993)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 87. Movie: It Could Happen to You (1994)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 88. Movie: Apartment, The (1960)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 89. Movie: Blue Chips (1994)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 90. Movie: Butcher Boy, The (1998)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 91. Movie: Cliffhanger (1993)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 92. Movie: Rob Roy (1995)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 93. Movie: Further Gesture, A (1996)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 94. Movie: Only You (1994)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 95. Movie: With Honors (1994)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 96. Movie: Of Love and Shadows (1994)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 97. Movie: Frisk (1995)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 98. Movie: Yankee Zulu (1994)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 99. Movie: Eraser (1996)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 100. Movie: Houseguest (1994)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 101. Movie: Other Voices, Other Rooms (1997)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 102. Movie: Hamlet (1996)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 103. Movie: In the Realm of the Senses (Ai no corrida) (1976)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 104. Movie: Adventures of Robin Hood, The (1938)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 105. Movie: Trial by Jury (1994)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 106. Movie: Van, The (1996)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 107. Movie: Strawberry and Chocolate (Fresa y chocolate) (1993)
# Predicted Rating: 5.0
# Confidence: 0.27
# ------------------------
# 108. Movie: Shallow Grave (1994)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 109. Movie: In Love and War (1996)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 110. Movie: Blues Brothers 2000 (1998)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 111. Movie: 8 1/2 (1963)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 112. Movie: Three Lives and Only One Death (1996)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 113. Movie: Feast of July (1995)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 114. Movie: Dingo (1992)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 115. Movie: Murder at 1600 (1997)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 116. Movie: Mute Witness (1994)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 117. Movie: 8 Heads in a Duffel Bag (1997)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 118. Movie: Absolute Power (1997)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 119. Movie: Postman, The (1997)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 120. Movie: Nick of Time (1995)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 121. Movie: Fallen (1998)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 122. Movie: Quiet Room, The (1996)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 123. Movie: Desperate Measures (1998)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 124. Movie: Out to Sea (1997)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 125. Movie: Murder in the First (1995)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 126. Movie: Bloody Child, The (1996)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 127. Movie: Fille seule, La (A Single Girl) (1995)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 128. Movie: Air Force One (1997)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 129. Movie: Lotto Land (1995)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 130. Movie: Batman (1989)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 131. Movie: Harriet the Spy (1996)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 132. Movie: Airheads (1994)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 133. Movie: Nosferatu (Nosferatu, eine Symphonie des Grauens) (1922)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 134. Movie: Die Hard: With a Vengeance (1995)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 135. Movie: Stalingrad (1993)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 136. Movie: Swept from the Sea (1997)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 137. Movie: Enchanted April (1991)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 138. Movie: Big Sleep, The (1946)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 139. Movie: Bad Taste (1987)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 140. Movie: Georgia (1995)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 141. Movie: Etz Hadomim Tafus (Under the Domin Tree) (1994)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 142. Movie: Time Tracers (1995)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 143. Movie: I'll Do Anything (1994)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 144. Movie: First Wives Club, The (1996)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 145. Movie: Pollyanna (1960)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 146. Movie: Star Trek: The Motion Picture (1979)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 147. Movie: Heaven's Prisoners (1996)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 148. Movie: Perez Family, The (1995)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 149. Movie: Secrets & Lies (1996)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 150. Movie: Rudy (1993)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 151. Movie: Return of Martin Guerre, The (Retour de Martin Guerre, Le) (1982)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 152. Movie: Sophie's Choice (1982)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 153. Movie: Invitation, The (Zaproszenie) (1986)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 154. Movie: Total Eclipse (1995)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 155. Movie: Gold Diggers: The Secret of Bear Mountain (1995)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 156. Movie: Letter From Death Row, A (1998)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 157. Movie: Celestial Clockwork (1994)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 158. Movie: Great Day in Harlem, A (1994)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 159. Movie: Screamers (1995)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 160. Movie: Drop Zone (1994)
# Predicted Rating: 5.0
# Confidence: 0.26
# ------------------------
# 161. Movie: Road to Wellville, The (1994)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 162. Movie: Dante's Peak (1997)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 163. Movie: Primary Colors (1998)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 164. Movie: Rhyme & Reason (1997)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 165. Movie: 187 (1997)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 166. Movie: Getting Even with Dad (1994)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 167. Movie: Maybe, Maybe Not (Bewegte Mann, Der) (1994)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 168. Movie: Locusts, The (1997)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 169. Movie: Crude Oasis, The (1995)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 170. Movie: Deceiver (1997)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 171. Movie: T-Men (1947)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 172. Movie: Canadian Bacon (1994)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 173. Movie: American Werewolf in London, An (1981)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 174. Movie: Super Mario Bros. (1993)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 175. Movie: Lawnmower Man 2: Beyond Cyberspace (1996)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 176. Movie: Sliding Doors (1998)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 177. Movie: Farewell to Arms, A (1932)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 178. Movie: World of Apu, The (Apur Sansar) (1959)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 179. Movie: Blue Sky (1994)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 180. Movie: Hard Target (1993)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 181. Movie: Relative Fear (1994)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 182. Movie: Power 98 (1995)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 183. Movie: Man Who Would Be King, The (1975)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 184. Movie: Chairman of the Board (1998)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 185. Movie: Nightwatch (1997)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 186. Movie: Timecop (1994)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 187. Movie: Fausto (1993)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 188. Movie: Star Maps (1997)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 189. Movie: To Have, or Not (1995)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 190. Movie: Shadow of Angels (Schatten der Engel) (1976)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 191. Movie: Picture Bride (1995)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 192. Movie: Peacemaker, The (1997)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 193. Movie: Mrs. Brown (Her Majesty, Mrs. Brown) (1997)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 194. Movie: Prisoner of the Mountains (Kavkazsky Plennik) (1996)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 195. Movie: B. Monkey (1998)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 196. Movie: Santa with Muscles (1996)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 197. Movie: Stupids, The (1996)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 198. Movie: Deep Rising (1998)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 199. Movie: Inspector General, The (1949)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 200. Movie: Washington Square (1997)
# Predicted Rating: 5.0
# Confidence: 0.25
# ------------------------
# 201. Movie: Designated Mourner, The (1997)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 202. Movie: Life with Mikey (1993)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 203. Movie: Lassie (1994)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 204. Movie: Specialist, The (1994)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 205. Movie: Around the World in 80 Days (1956)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 206. Movie: Jack and Sarah (1995)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 207. Movie: L.A. Confidential (1997)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 208. Movie: Two or Three Things I Know About Her (1966)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 209. Movie: Vermin (1998)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 210. Movie: Tie Me Up! Tie Me Down! (1990)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 211. Movie: ï¿½ kï¿½ldum klaka (Cold Fever) (1994)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 212. Movie: Saint, The (1997)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 213. Movie: Poison Ivy II (1995)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 214. Movie: M. Butterfly (1993)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 215. Movie: Seven Years in Tibet (1997)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 216. Movie: Piano, The (1993)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 217. Movie: Leopard Son, The (1996)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 218. Movie: Interview with the Vampire (1994)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 219. Movie: Land Before Time III: The Time of the Great Giving (1995) (V)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 220. Movie: Davy Crockett, King of the Wild Frontier (1955)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 221. Movie: Pump Up the Volume (1990)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 222. Movie: Bastard Out of Carolina (1996)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 223. Movie: My Life as a Dog (Mitt liv som hund) (1985)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 224. Movie: Critical Care (1997)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 225. Movie: Jungle Book, The (1994)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 226. Movie: Paris Was a Woman (1995)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 227. Movie: Girls Town (1996)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 228. Movie: Butterfly Kiss (1995)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 229. Movie: Nosferatu a Venezia (1986)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 230. Movie: Goofy Movie, A (1995)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 231. Movie: Stranger, The (1994)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 232. Movie: Nobody's Fool (1994)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 233. Movie: Scream of Stone (Schrei aus Stein) (1991)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 234. Movie: Wild Bunch, The (1969)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 235. Movie: Evita (1996)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 236. Movie: Jack (1996)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 237. Movie: Denise Calls Up (1995)
# Predicted Rating: 5.0
# Confidence: 0.24
# ------------------------
# 238. Movie: Cape Fear (1962)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 239. Movie: White Squall (1996)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 240. Movie: Shadows (Cienie) (1988)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 241. Movie: Stealing Beauty (1996)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 242. Movie: Ghosts of Mississippi (1996)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 243. Movie: Sphere (1998)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 244. Movie: Big Blue, The (Grand bleu, Le) (1988)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 245. Movie: House of the Spirits, The (1993)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 246. Movie: Inkwell, The (1994)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 247. Movie: Jury Duty (1995)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 248. Movie: Tetsuo II: Body Hammer (1992)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 249. Movie: Turbulence (1997)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 250. Movie: Venice/Venice (1992)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 251. Movie: Microcosmos: Le peuple de l'herbe (1996)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 252. Movie: Boys Life (1995)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 253. Movie: Modern Affair, A (1995)
# Predicted Rating: 5.0
# Confidence: 0.23
# ------------------------
# 254. Movie: Metisse (Cafï¿½ au Lait) (1993)
# Predicted Rating: 5.0
# Confidence: 0.22
# ------------------------
# 255. Movie: Once Upon a Time in the West (1969)
# Predicted Rating: 5.0
# Confidence: 0.22
# ------------------------
# 256. Movie: Chamber, The (1996)
# Predicted Rating: 5.0
# Confidence: 0.22
# ------------------------
# 257. Movie: Scarlet Letter, The (1926)
# Predicted Rating: 5.0
# Confidence: 0.20
# ------------------------
# 258. Movie: Hear My Song (1991)
# Predicted Rating: 4.0
# Confidence: 0.26
# ------------------------
# 259. Movie: War Room, The (1993)
# Predicted Rating: 4.0
# Confidence: 0.25
# ------------------------
# 260. Movie: First Kid (1996)
# Predicted Rating: 4.0
# Confidence: 0.24
# ------------------------
# 261. Movie: Father of the Bride Part II (1995)
# Predicted Rating: 4.0
# Confidence: 0.22
# ------------------------
# 262. Movie: Color of Night (1994)
# Predicted Rating: 4.0
# Confidence: 0.22
# ------------------------
# 263. Movie: Wolf (1994)
# Predicted Rating: 3.0
# Confidence: 0.37
# ------------------------
# 264. Movie: Death in the Garden (Mort en ce jardin, La) (1956)
# Predicted Rating: 3.0
# Confidence: 0.37
# ------------------------
# 265. Movie: The Courtyard (1995)
# Predicted Rating: 3.0
# Confidence: 0.37
# ------------------------
# 266. Movie: Father of the Bride (1950)
# Predicted Rating: 3.0
# Confidence: 0.36
# ------------------------
# 267. Movie: Innocent Sleep, The (1995)
# Predicted Rating: 3.0
# Confidence: 0.36
# ------------------------
# 268. Movie: Picnic (1955)
# Predicted Rating: 3.0
# Confidence: 0.36
# ------------------------
# 269. Movie: Aparajito (1956)
# Predicted Rating: 3.0
# Confidence: 0.36
# ------------------------
# 270. Movie: Gay Divorcee, The (1934)
# Predicted Rating: 3.0
# Confidence: 0.36
# ------------------------
# 271. Movie: Smile Like Yours, A (1997)
# Predicted Rating: 3.0
# Confidence: 0.35
# ------------------------
# 272. Movie: Hostile Intentions (1994)
# Predicted Rating: 3.0
# Confidence: 0.35
# ------------------------
# 273. Movie: Open Season (1996)
# Predicted Rating: 3.0
# Confidence: 0.35
# ------------------------
# 274. Movie: Addicted to Love (1997)
# Predicted Rating: 3.0
# Confidence: 0.35
# ------------------------
# 275. Movie: Losing Isaiah (1995)
# Predicted Rating: 3.0
# Confidence: 0.35
# ------------------------
# 276. Movie: Here Comes Cookie (1935)
# Predicted Rating: 3.0
# Confidence: 0.35
# ------------------------
# 277. Movie: Menace II Society (1993)
# Predicted Rating: 3.0
# Confidence: 0.35
# ------------------------
# 278. Movie: Beverly Hillbillies, The (1993)
# Predicted Rating: 3.0
# Confidence: 0.35
# ------------------------
# 279. Movie: Promesse, La (1996)
# Predicted Rating: 3.0
# Confidence: 0.34
# ------------------------
# 280. Movie: Volcano (1997)
# Predicted Rating: 3.0
# Confidence: 0.34
# ------------------------
# 281. Movie: Wedding Singer, The (1998)
# Predicted Rating: 3.0
# Confidence: 0.34
# ------------------------
# 282. Movie: Joe's Apartment (1996)
# Predicted Rating: 3.0
# Confidence: 0.34
# ------------------------
# 283. Movie: Dazed and Confused (1993)
# Predicted Rating: 3.0
# Confidence: 0.34
# ------------------------
# 284. Movie: Pyromaniac's Love Story, A (1995)
# Predicted Rating: 3.0
# Confidence: 0.34
# ------------------------
# 285. Movie: Real Genius (1985)
# Predicted Rating: 3.0
# Confidence: 0.34
# ------------------------
# 286. Movie: Grateful Dead (1995)
# Predicted Rating: 3.0
# Confidence: 0.34
# ------------------------
# 287. Movie: Clockers (1995)
# Predicted Rating: 3.0
# Confidence: 0.34
# ------------------------
# 288. Movie: Night of the Living Dead (1968)
# Predicted Rating: 3.0
# Confidence: 0.34
# ------------------------
# 289. Movie: Nine Months (1995)
# Predicted Rating: 3.0
# Confidence: 0.34
# ------------------------
# 290. Movie: Race the Sun (1996)
# Predicted Rating: 3.0
# Confidence: 0.34
# ------------------------
# 291. Movie: Convent, The (Convento, O) (1995)
# Predicted Rating: 3.0
# Confidence: 0.34
# ------------------------
# 292. Movie: Body Snatchers (1993)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 293. Movie: Delta of Venus (1994)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 294. Movie: Death and the Maiden (1994)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 295. Movie: Great Expectations (1998)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 296. Movie: Conspiracy Theory (1997)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 297. Movie: Men With Guns (1997)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 298. Movie: Leaving Las Vegas (1995)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 299. Movie: Nutty Professor, The (1996)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 300. Movie: Destiny Turns on the Radio (1995)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 301. Movie: I'm Not Rappaport (1996)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 302. Movie: Barb Wire (1996)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 303. Movie: Last Time I Committed Suicide, The (1997)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 304. Movie: Set It Off (1996)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 305. Movie: Innocents, The (1961)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 306. Movie: Maltese Falcon, The (1941)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 307. Movie: Mark of Zorro, The (1940)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 308. Movie: Inventing the Abbotts (1997)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 309. Movie: Flesh and Bone (1993)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 310. Movie: Chain Reaction (1996)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 311. Movie: Kicked in the Head (1997)
# Predicted Rating: 3.0
# Confidence: 0.33
# ------------------------
# 312. Movie: Kalifornia (1993)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 313. Movie: Lover's Knot (1996)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 314. Movie: Highlander III: The Sorcerer (1994)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 315. Movie: Reluctant Debutante, The (1958)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 316. Movie: Escape to Witch Mountain (1975)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 317. Movie: Feeling Minnesota (1996)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 318. Movie: Junior (1994)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 319. Movie: Trial and Error (1997)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 320. Movie: Crossfire (1947)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 321. Movie: Two Much (1996)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 322. Movie: Renaissance Man (1994)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 323. Movie: For Love or Money (1993)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 324. Movie: Grumpier Old Men (1995)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 325. Movie: Virtuosity (1995)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 326. Movie: Quest, The (1996)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 327. Movie: Contempt (Mï¿½pris, Le) (1963)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 328. Movie: Candidate, The (1972)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 329. Movie: Shooting Fish (1997)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 330. Movie: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 331. Movie: Anastasia (1997)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 332. Movie: Surviving Picasso (1996)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 333. Movie: Last Man Standing (1996)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 334. Movie: Nothing to Lose (1994)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 335. Movie: Traveller (1997)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 336. Movie: Man of No Importance, A (1994)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 337. Movie: Money Talks (1997)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 338. Movie: Waterworld (1995)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 339. Movie: Babyfever (1994)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 340. Movie: Gang Related (1997)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 341. Movie: My Life and Times With Antonin Artaud (En compagnie d'Antonin Artaud) (1993)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 342. Movie: Sum of Us, The (1994)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 343. Movie: Sixth Man, The (1997)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 344. Movie: So Dear to My Heart (1949)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 345. Movie: Nina Takes a Lover (1994)
# Predicted Rating: 3.0
# Confidence: 0.32
# ------------------------
# 346. Movie: Jimmy Hollywood (1994)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 347. Movie: Gandhi (1982)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 348. Movie: Another Stakeout (1993)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 349. Movie: Fear of a Black Hat (1993)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 350. Movie: Even Cowgirls Get the Blues (1993)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 351. Movie: Dangerous Ground (1997)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 352. Movie: Grosse Fatigue (1994)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 353. Movie: Damsel in Distress, A (1937)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 354. Movie: Broken English (1996)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 355. Movie: Hellraiser: Bloodline (1996)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 356. Movie: Spawn (1997)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 357. Movie: Rosewood (1997)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 358. Movie: I, Worst of All (Yo, la peor de todas) (1990)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 359. Movie: Mamma Roma (1962)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 360. Movie: Cure, The (1995)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 361. Movie: That Old Feeling (1997)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 362. Movie: Grass Harp, The (1995)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 363. Movie: Apple Dumpling Gang, The (1975)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 364. Movie: Daens (1992)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 365. Movie: Clean Slate (1994)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 366. Movie: Cinderella (1950)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 367. Movie: Two Bits (1995)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 368. Movie: Pinocchio (1940)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 369. Movie: Newton Boys, The (1998)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 370. Movie: Manchurian Candidate, The (1962)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 371. Movie: Funny Face (1957)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 372. Movie: Love Affair (1994)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 373. Movie: Bio-Dome (1996)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 374. Movie: Addiction, The (1995)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 375. Movie: Passion Fish (1992)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 376. Movie: Smoke (1995)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 377. Movie: Pather Panchali (1955)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 378. Movie: Geronimo: An American Legend (1993)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 379. Movie: Sprung (1997)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 380. Movie: Clueless (1995)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 381. Movie: Endless Summer 2, The (1994)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 382. Movie: Glimmer Man, The (1996)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 383. Movie: Meet Wally Sparks (1997)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 384. Movie: Children of the Revolution (1996)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 385. Movie: Coldblooded (1995)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 386. Movie: Ace Ventura: When Nature Calls (1995)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 387. Movie: Reality Bites (1994)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 388. Movie: Mr. Magoo (1997)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 389. Movie: Corrina, Corrina (1994)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 390. Movie: Rear Window (1954)
# Predicted Rating: 3.0
# Confidence: 0.31
# ------------------------
# 391. Movie: Death in Brunswick (1991)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 392. Movie: Farewell My Concubine (1993)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 393. Movie: Relic, The (1997)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 394. Movie: To Die For (1995)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 395. Movie: Othello (1995)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 396. Movie: Afterglow (1997)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 397. Movie: Up in Smoke (1978)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 398. Movie: Courage Under Fire (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 399. Movie: Alien: Resurrection (1997)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 400. Movie: Big Bully (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 401. Movie: Year of the Horse (1997)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 402. Movie: Assassins (1995)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 403. Movie: Fled (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 404. Movie: Some Like It Hot (1959)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 405. Movie: Cyclo (1995)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 406. Movie: Big Squeeze, The (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 407. Movie: Fair Game (1995)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 408. Movie: Caught (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 409. Movie: Spice World (1997)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 410. Movie: Beautiful Girls (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 411. Movie: Story of Xinghua, The (1993)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 412. Movie: Hard Rain (1998)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 413. Movie: Cops and Robbersons (1994)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 414. Movie: Little City (1998)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 415. Movie: Penny Serenade (1941)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 416. Movie: Assignment, The (1997)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 417. Movie: Gordy (1995)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 418. Movie: Sunset Park (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 419. Movie: Laura (1944)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 420. Movie: Whole Wide World, The (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 421. Movie: Faithful (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 422. Movie: Believers, The (1987)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 423. Movie: Wishmaster (1997)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 424. Movie: August (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 425. Movie: Boogie Nights (1997)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 426. Movie: Trees Lounge (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 427. Movie: Jade (1995)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 428. Movie: Man in the Iron Mask, The (1998)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 429. Movie: Winter Guest, The (1997)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 430. Movie: Mr. Wrong (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 431. Movie: Omen, The (1976)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 432. Movie: Third Man, The (1949)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 433. Movie: Dave (1993)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 434. Movie: Marvin's Room (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 435. Movie: Cowboy Way, The (1994)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 436. Movie: Mad Dog Time (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 437. Movie: Simple Twist of Fate, A (1994)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 438. Movie: Stripes (1981)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 439. Movie: Land and Freedom (Tierra y libertad) (1995)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 440. Movie: Christmas Carol, A (1938)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 441. Movie: Something to Talk About (1995)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 442. Movie: Pushing Hands (1992)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 443. Movie: Secret Garden, The (1993)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 444. Movie: Female Perversions (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 445. Movie: Love and Death on Long Island (1997)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 446. Movie: His Girl Friday (1940)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 447. Movie: Funeral, The (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 448. Movie: Late Bloomers (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 449. Movie: Just Cause (1995)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 450. Movie: Trainspotting (1996)
# Predicted Rating: 3.0
# Confidence: 0.30
# ------------------------
# 451. Movie: Buddy (1997)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 452. Movie: Squeeze (1996)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 453. Movie: In the Name of the Father (1993)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 454. Movie: Temptress Moon (Feng Yue) (1996)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 455. Movie: When a Man Loves a Woman (1994)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 456. Movie: Three Caballeros, The (1945)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 457. Movie: Fire on the Mountain (1996)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 458. Movie: Shadowlands (1993)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 459. Movie: National Lampoon's Senior Trip (1995)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 460. Movie: City of Angels (1998)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 461. Movie: Ghost in the Shell (Kokaku kidotai) (1995)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 462. Movie: Hurricane Streets (1998)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 463. Movie: Steal Big, Steal Little (1995)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 464. Movie: Multiplicity (1996)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 465. Movie: Donnie Brasco (1997)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 466. Movie: Perfect World, A (1993)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 467. Movie: Mighty, The (1998)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 468. Movie: Midnight in the Garden of Good and Evil (1997)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 469. Movie: Hurricane Streets (1998)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 470. Movie: Caro Diario (Dear Diary) (1994)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 471. Movie: Bhaji on the Beach (1993)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 472. Movie: Last Action Hero (1993)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 473. Movie: Powder (1995)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 474. Movie: Mallrats (1995)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 475. Movie: Great White Hype, The (1996)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 476. Movie: Dark City (1998)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 477. Movie: English Patient, The (1996)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# 478. Movie: Highlander (1986)
# Predicted Rating: 3.0
# Confidence: 0.29
# ------------------------
# ...
# 1253. Movie: Speed 2: Cruise Control (1997)
# Predicted Rating: 2.0
# Confidence: 0.27
# ------------------------
# 1254. Movie: Paradise Road (1997)
# Predicted Rating: 2.0
# Confidence: 0.27
# ------------------------
# 1255. Movie: Best Men (1997)
# Predicted Rating: 2.0
# Confidence: 0.27
# ------------------------
# 1256. Movie: Shaggy Dog, The (1959)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1257. Movie: Ulee's Gold (1997)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1258. Movie: Machine, The (1994)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1259. Movie: Phantom, The (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1260. Movie: Killing Zoe (1994)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1261. Movie: Radioland Murders (1994)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1262. Movie: When We Were Kings (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1263. Movie: Boomerang (1992)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1264. Movie: Girl 6 (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1265. Movie: Englishman Who Went Up a Hill, But Came Down a Mountain, The (1995)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1266. Movie: All Over Me (1997)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1267. Movie: Amityville: Dollhouse (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1268. Movie: Amityville Horror, The (1979)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1269. Movie: Aladdin and the King of Thieves (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1270. Movie: Everest (1998)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1271. Movie: Giant (1956)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1272. Movie: Albino Alligator (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1273. Movie: Swiss Family Robinson (1960)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1274. Movie: Commandments (1997)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1275. Movie: Black Beauty (1994)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1276. Movie: Mouse Hunt (1997)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1277. Movie: Captives (1994)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1278. Movie: Bed of Roses (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1279. Movie: Burnt Offerings (1976)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1280. Movie: Mrs. Parker and the Vicious Circle (1994)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1281. Movie: Crying Game, The (1992)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1282. Movie: What's Love Got to Do with It (1993)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1283. Movie: Secret Agent, The (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1284. Movie: One Flew Over the Cuckoo's Nest (1975)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1285. Movie: Girl in the Cadillac (1995)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1286. Movie: Heavenly Creatures (1994)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1287. Movie: They Made Me a Criminal (1939)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1288. Movie: Amityville Curse, The (1990)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1289. Movie: Johnny Mnemonic (1995)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1290. Movie: City Hall (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1291. Movie: Wonderful, Horrible Life of Leni Riefenstahl, The (1993)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1292. Movie: Two if by Sea (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1293. Movie: Fierce Creatures (1997)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1294. Movie: Chungking Express (1994)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1295. Movie: Substance of Fire, The (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1296. Movie: Sudden Manhattan (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1297. Movie: Alphaville (1965)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1298. Movie: Marked for Death (1990)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1299. Movie: Treasure of the Sierra Madre, The (1948)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1300. Movie: Slingshot, The (1993)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1301. Movie: Fear (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1302. Movie: Glory (1989)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1303. Movie: Juror, The (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1304. Movie: I Like It Like That (1994)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1305. Movie: Waiting for Guffman (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1306. Movie: Cabin Boy (1994)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1307. Movie: Amateur (1994)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1308. Movie: Beautiful Thing (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1309. Movie: American Buffalo (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1310. Movie: Terminal Velocity (1994)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1311. Movie: Ed (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1312. Movie: Walking Dead, The (1995)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1313. Movie: Kiss of Death (1995)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1314. Movie: Mission: Impossible (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1315. Movie: Some Kind of Wonderful (1987)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1316. Movie: Office Killer (1997)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1317. Movie: I Love Trouble (1994)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1318. Movie: Killer: A Journal of Murder (1995)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1319. Movie: Ghost (1990)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1320. Movie: All About Eve (1950)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1321. Movie: Twisted (1996)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1322. Movie: 39 Steps, The (1935)
# Predicted Rating: 2.0
# Confidence: 0.26
# ------------------------
# 1323. Movie: Collectionneuse, La (1967)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1324. Movie: Month by the Lake, A (1995)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1325. Movie: Magnificent Seven, The (1954)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1326. Movie: Sliding Doors (1998)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1327. Movie: Mortal Kombat: Annihilation (1997)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1328. Movie: Preacher's Wife, The (1996)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1329. Movie: Bronx Tale, A (1993)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1330. Movie: Home Alone 3 (1997)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1331. Movie: Beverly Hills Cop III (1994)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1332. Movie: Annie Hall (1977)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1333. Movie: Jumanji (1995)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1334. Movie: Perfect Candidate, A (1996)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1335. Movie: Princess Caraboo (1994)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1336. Movie: Horse Whisperer, The (1998)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1337. Movie: Johns (1996)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1338. Movie: Ladybird Ladybird (1994)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1339. Movie: Kika (1993)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1340. Movie: Nï¿½nette et Boni (1996)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1341. Movie: Career Girls (1997)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1342. Movie: Ayn Rand: A Sense of Life (1997)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1343. Movie: Adventures of Pinocchio, The (1996)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1344. Movie: Vampire in Brooklyn (1995)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1345. Movie: MURDER and murder (1996)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1346. Movie: Across the Sea of Time (1995)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1347. Movie: Kissed (1996)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1348. Movie: Bushwhacked (1995)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1349. Movie: Mondo (1996)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1350. Movie: Boys (1996)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1351. Movie: Somebody to Love (1994)
# Predicted Rating: 2.0
# Confidence: 0.25
# ------------------------
# 1352. Movie: FairyTale: A True Story (1997)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1353. Movie: Unzipped (1995)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1354. Movie: Made in America (1993)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1355. Movie: Higher Learning (1995)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1356. Movie: Secret of Roan Inish, The (1994)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1357. Movie: House Party 3 (1994)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1358. Movie: The Deadly Cure (1996)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1359. Movie: Shadow Conspiracy (1997)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1360. Movie: Walk in the Clouds, A (1995)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1361. Movie: Amityville: A New Generation (1993)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1362. Movie: Wild America (1997)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1363. Movie: Walk in the Sun, A (1945)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1364. Movie: Purple Noon (1960)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1365. Movie: Big Lebowski, The (1998)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1366. Movie: Until the End of the World (Bis ans Ende der Welt) (1991)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1367. Movie: Bonnie and Clyde (1967)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1368. Movie: Love Is All There Is (1996)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1369. Movie: Golden Earrings (1947)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1370. Movie: Notorious (1946)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1371. Movie: Pest, The (1997)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1372. Movie: Chinatown (1974)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1373. Movie: Body Snatchers (1993)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1374. Movie: What Happened Was... (1994)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1375. Movie: Turning, The (1992)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1376. Movie: Bitter Sugar (Azucar Amargo) (1996)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1377. Movie: Pagemaster, The (1994)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1378. Movie: Dumbo (1941)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1379. Movie: Coneheads (1993)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1380. Movie: Ill Gotten Gains (1997)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1381. Movie: To Catch a Thief (1955)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1382. Movie: Client, The (1994)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1383. Movie: Search for One-eye Jimmy, The (1996)
# Predicted Rating: 2.0
# Confidence: 0.24
# ------------------------
# 1384. Movie: Addams Family Values (1993)
# Predicted Rating: 2.0
# Confidence: 0.23
# ------------------------
# 1385. Movie: True Crime (1995)
# Predicted Rating: 2.0
# Confidence: 0.23
# ------------------------
# 1386. Movie: Spellbound (1945)
# Predicted Rating: 2.0
# Confidence: 0.23
# ------------------------
# 1387. Movie: Rosencrantz and Guildenstern Are Dead (1990)
# Predicted Rating: 2.0
# Confidence: 0.23
# ------------------------
# 1388. Movie: Parent Trap, The (1961)
# Predicted Rating: 2.0
# Confidence: 0.23
# ------------------------
# 1389. Movie: Jefferson in Paris (1995)
# Predicted Rating: 2.0
# Confidence: 0.23
# ------------------------
# 1390. Movie: Tombstone (1993)
# Predicted Rating: 2.0
# Confidence: 0.23
# ------------------------
# 1391. Movie: Prophecy, The (1995)
# Predicted Rating: 2.0
# Confidence: 0.23
# ------------------------
# 1392. Movie: Desperate Measures (1998)
# Predicted Rating: 2.0
# Confidence: 0.23
# ------------------------
# 1393. Movie: Fly Away Home (1996)
# Predicted Rating: 2.0
# Confidence: 0.23
# ------------------------
# 1394. Movie: Young Guns II (1990)
# Predicted Rating: 2.0
# Confidence: 0.23
# ------------------------
# 1395. Movie: Oscar & Lucinda (1997)
# Predicted Rating: 2.0
# Confidence: 0.23
# ------------------------
# 1396. Movie: Boys, Les (1997)
# Predicted Rating: 2.0
# Confidence: 0.23
# ------------------------
# 1397. Movie: My Favorite Year (1982)
# Predicted Rating: 2.0
# Confidence: 0.23
# ------------------------
# 1398. Movie: Reckless (1995)
# Predicted Rating: 2.0
# Confidence: 0.22
# ------------------------
# 1399. Movie: Winnie the Pooh and the Blustery Day (1968)
# Predicted Rating: 2.0
# Confidence: 0.22
# ------------------------
# 1400. Movie: People vs. Larry Flynt, The (1996)
# Predicted Rating: 2.0
# Confidence: 0.22
# ------------------------
# 1401. Movie: East of Eden (1955)
# Predicted Rating: 1.0
# Confidence: 0.27
# ------------------------
# 1402. Movie: Stonewall (1995)
# Predicted Rating: 1.0
# Confidence: 0.25
# ------------------------
# 1403. Movie: Stars Fell on Henrietta, The (1995)
# Predicted Rating: 1.0
# Confidence: 0.25
# ------------------------
# 1404. Movie: Four Days in September (1997)
# Predicted Rating: 1.0
# Confidence: 0.25
# ------------------------
# 1405. Movie: Lightning Jack (1994)
# Predicted Rating: 1.0
# Confidence: 0.24
# ------------------------
# 1406. Movie: Pretty Woman (1990)
# Predicted Rating: 1.0
# Confidence: 0.23
# ------------------------
# 1407. Movie: Fathers' Day (1997)
# Predicted Rating: 1.0
# Confidence: 0.23
# ------------------------
# 1408. Movie: Ransom (1996)
# Predicted Rating: 1.0
# Confidence: 0.23
# ------------------------
# 1409. Movie: Lay of the Land, The (1997)
# Predicted Rating: 1.0
# Confidence: 0.22
# ------------------------
# 1410. Movie: Hoodlum (1997)
# Predicted Rating: 1.0
# Confidence: 0.21
# ------------------------
